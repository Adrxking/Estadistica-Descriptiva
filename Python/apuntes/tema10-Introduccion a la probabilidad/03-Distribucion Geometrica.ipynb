# %% [markdown]
# ## Distribucion Geometrica

# %%
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(1,1)

p = 0.3

mean, var, skew, kurt = geom.stats(p, moments = 'mvsk')
print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f"%skew)
print("Curtosis %f"%kurt)

x = np.arange(geom.ppf(0.01, p), geom.ppf(0.99, p))
ax.plot(x, geom.ppf(x, p), 'bo', ms = 8, 
        label = "Funcion de probabilidad de Geom(0.3)")
ax.vlines(x, 0, geom.pmf(x, p), colors = 'b', lw = 4, alpha = 0.5)

rv = geom(p)
ax.vlines(x, 0, rv.pmf(x), colors = 'k', linestyles = '--', lw = 1, label = "Frozen PMF")
ax.legend(loc = 'best')
plt.show()
# Out:
# Media 3.333333
# Varianza 7.777778
# Sesgo 2.031889
# Curtosis 6.128571

# %%
fig, ax = plt.subplots(1,1)
r = geom.rvs(p, size = 10000)
plt.hist(r)
plt.show()

# %%
# Distribucion acumulada
fig, ax = plt.subplots(1,1)
prob = geom.cdf(x, p)
ax.plot(x, prob, 'bo', ms = 8, label = "Funcion de distribucion acumulada")
plt.show()
